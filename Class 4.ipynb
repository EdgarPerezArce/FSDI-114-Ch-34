# %%
# SinglyLinkedList implementation


class SinglyLinkedList:
    class Node:
        def __init__(self, data):
            self.data = data
            self.next = None
            
    def __init__(self):
        self.head = None
        
    def append(self, value):
        new_node = self.Node(value)
        if not self.head:             # if self.head ==None
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
    
    def insert(self, index, value):
        pass
    
    def __str__(self):
        out = "["
        if self.head:
            out += "%s" % self.head.data
            current = self.head.next
            while current:               # while current != None
                out += ", %s" % current.data
                current = current.next
        out += "]"
        return out

# %%
# How python usally prints lists:
# Empty list:
print([])
# List with a single element:
print([1])
# List with more than one element:
print([1, 2, 3])
# Out:
# []
# [1]
# [1, 2, 3]

# %%
sll = SinglyLinkedList()

# Empty list:
print(sll)

sll.append(1)
print(sll)

# List with more than one element:
for number in range(1, 4):
    sll.append(number)
    
print(sll)
# Out:
# []
# [1]
# [1, 1, 2, 3]

# %%
mylist = [1, 2, 3]

mylist.insert(100, 100)

print(mylist)

help(mylist)
# Out:
# [1, 2, 3, 100]
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
# Pseudocode implimentation of insert
# define function insert with parameters index and value:
# create a new node with the provided value
# if the list is empty            // repreesented by the fact that the head is set to None
    # then, simply update our new node's "next" reference so it points to the head
    # and, update the head refernce so it points to our new node.
# otherwise
    # // we need to validate that the index is within our list
    # // create a variable to keep track of how many times we;ve traversed (moved from one node to the other)
    # count = 0
    # my variable current is set to the head node
    # create a reference to a previous node (called previous) which starts off as None
    # while count does not equale index and there is a next node to traverse into
        # current is updated to the next node in the sequence
        # add 1 to count
    # if perivous was never updated, then, it means there was only one node in my list
        # append the newly created node to my list
    # otherwise, if count is equal to the given index:
    # // this means, we were able to find the index within the scope of our list
    # previous' next reference is updated to point to current
        # otherwise
        # // this case happens when index > count
        # append the newly created node to my list

# %%
# Doubly Linked List implementation

class DoublyLinkedList:
    class Node:
        def __init__(self, data):
            self.data = data
            self.next = None
            self.prev = None
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0
        
    def append(self, value):
        new_node = self.Node(value)
        if self.tail:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.length += 1
        if not self.head:
            self.head = new_node
            self.tail = new_node
            self.length += 1
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            new_node.prev = current
            self.length += 1
            
    def search(self, value):
        if not self.head:
            return False
        else:
            current = self.head
            tail = self.tail
            while current.data != tail:
                # traverse
                if current.data != value and tail.data != value:
                    current = current.next
                    tail = tail.prev
                else:
                    return True
        return False
        
        #implement binary search as a method to this class (DLL)
    def binary_search(self, value):
        # 
            
    def __str__(self):
        out = "["
        if self.head:
            out += "%s" % self.head.data
            current = self.head.next
            while current:
                out += ", %s" % current.data
                current = current.next
        out += "]"
        return out

# %%
ddl = DoubllyLinkList()

print([])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ddl = DoubllyLinkList()
#       3 print([])
#
# NameError: name 'DoubllyLinkList' is not defined

# %% [markdown]
# # Challenge 1
#
# ### Given two intergers as parameters, create a box. The box must be comprised of "*".
#
# #### Example:
#
# ```
# my function(2, 2) should return:
#
# **
# **
#
# my function(3, 3) should return:
# ***
# * *
# ***
#
# myfunction(5, 5) should return:
# *****
# *   *
# *   *
# *   *
# *****
# ```
#
# Parameters will not always be the same.
